# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
#import time
#from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | eureka
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | buala
# Processing Record 7 of Set 1 | bac lieu
# Processing Record 8 of Set 1 | xining
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | muravlenko
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | kargasok
# Processing Record 14 of Set 1 | morrinhos
# Processing Record 15 of Set 1 | zhigansk
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | faya
# Processing Record 20 of Set 1 | punta alta
# Processing Record 21 of Set 1 | korla
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | lata
# Processing Record 24 of Set 1 | navrongo
# Processing Record 25 of Set 1 | barrow
# Processing Record 26 of Set 1 | sisimiut
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | suzaka
# Processing Record 35 of Set 1 | sebinkarahisar
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | presidencia roque saenz pena
# Processing Record 39 of Set 1 | namatanai
# Processing Record 40 of Set 1 | coahuayana
# Processing Record 41 of Set 1 | caravelas
# Processing Record 42 of Set 1 | nome
# Processing Record 43 of Set 1 | ankazoabo
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | pereira barreto
# Processing Record 49 of Set 1 | shihezi
# Processing Record 50 of Set 1 | sur
# Processing Record 1 of Set 2 | port-gentil
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | zyryanovsk
# Processing Record 5 of Set 2 | yinchuan
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | bathsheba
# Processing Record 11 of Set 2 | rabaul
# Processing Record 12 of Set 2 | poptun
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | surab
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | jaciara
# Processing Record 19 of Set 2 | okhotsk
# Processing Record 20 of Set 2 | bereda
# Processing Record 21 of Set 2 | port lincoln
# Processing Record 22 of Set 2 | kavaratti
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | mookane
# Processing Record 29 of Set 2 | vanavara
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | sobolevo
# Processing Record 33 of Set 2 | yumen
# Processing Record 34 of Set 2 | oksfjord
# Processing Record 35 of Set 2 | lukang
# Processing Record 36 of Set 2 | mount isa
# Processing Record 37 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | copiapo
# Processing Record 40 of Set 2 | kashiwazaki
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | sorland
# Processing Record 45 of Set 2 | west bay
# Processing Record 46 of Set 2 | labuhan
# Processing Record 47 of Set 2 | vrangel
# Processing Record 48 of Set 2 | kenitra
# Processing Record 49 of Set 2 | ushuaia
# Processing Record 50 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 3 | sarangani
# Processing Record 2 of Set 3 | abonnema
# Processing Record 3 of Set 3 | shenjiamen
# Processing Record 4 of Set 3 | clyde river
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | mecca
# Processing Record 10 of Set 3 | boa vista
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | tayu
# Processing Record 14 of Set 3 | ambilobe
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | san cristobal
# Processing Record 17 of Set 3 | batticaloa
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | yellowknife
# Processing Record 21 of Set 3 | tautira
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | hsinying
# City not found. Skipping...
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | saint-donat-de-montcalm
# Processing Record 26 of Set 3 | mount gambier
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | camacha
# Processing Record 29 of Set 3 | los llanos de aridane
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | panjab
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | the valley
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | terrace
# Processing Record 37 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 3 | hvide sande
# Processing Record 39 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | hambantota
# Processing Record 41 of Set 3 | jalingo
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | grunstadt
# Processing Record 44 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 45 of Set 3 | koundara
# Processing Record 46 of Set 3 | kinanah
# City not found. Skipping...
# Processing Record 47 of Set 3 | vryheid
# Processing Record 48 of Set 3 | castelldefels
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | zlobin
# Processing Record 1 of Set 4 | rudnogorsk
# Processing Record 2 of Set 4 | sechura
# Processing Record 3 of Set 4 | kudahuvadhoo
# Processing Record 4 of Set 4 | kushalgarh
# Processing Record 5 of Set 4 | may pen
# Processing Record 6 of Set 4 | srivardhan
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | mnogovershinnyy
# Processing Record 9 of Set 4 | beloha
# Processing Record 10 of Set 4 | praia da vitoria
# Processing Record 11 of Set 4 | atar
# Processing Record 12 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 13 of Set 4 | chapais
# Processing Record 14 of Set 4 | chulman
# Processing Record 15 of Set 4 | mahajanga
# Processing Record 16 of Set 4 | henderson
# Processing Record 17 of Set 4 | rio grande
# Processing Record 18 of Set 4 | fare
# Processing Record 19 of Set 4 | diffa
# Processing Record 20 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 21 of Set 4 | nieuw amsterdam
# Processing Record 22 of Set 4 | evensk
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | mamit
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | kilindoni
# Processing Record 27 of Set 4 | tiarei
# Processing Record 28 of Set 4 | amapa
# Processing Record 29 of Set 4 | vicuna
# Processing Record 30 of Set 4 | castro
# Processing Record 31 of Set 4 | sterling
# Processing Record 32 of Set 4 | dabat
# Processing Record 33 of Set 4 | sindhnur
# Processing Record 34 of Set 4 | tatarsk
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | tura
# Processing Record 37 of Set 4 | joao pinheiro
# Processing Record 38 of Set 4 | saskylakh
# Processing Record 39 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | villarrica
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | la ronge
# Processing Record 45 of Set 4 | waingapu
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | burnie
# Processing Record 48 of Set 4 | erie
# Processing Record 49 of Set 4 | teya
# Processing Record 50 of Set 4 | tevaitoa
# Processing Record 1 of Set 5 | oblivskaya
# Processing Record 2 of Set 5 | nampula
# Processing Record 3 of Set 5 | sokolo
# Processing Record 4 of Set 5 | kahului
# Processing Record 5 of Set 5 | portland
# Processing Record 6 of Set 5 | marquette
# Processing Record 7 of Set 5 | saurimo
# Processing Record 8 of Set 5 | tongliao
# Processing Record 9 of Set 5 | adrar
# Processing Record 10 of Set 5 | hulan
# Processing Record 11 of Set 5 | simbahan
# Processing Record 12 of Set 5 | rongcheng
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | ngunguru
# Processing Record 15 of Set 5 | acapulco
# Processing Record 16 of Set 5 | nicolas bravo
# Processing Record 17 of Set 5 | marysville
# Processing Record 18 of Set 5 | oissel
# Processing Record 19 of Set 5 | nalut
# Processing Record 20 of Set 5 | tintesti
# Processing Record 21 of Set 5 | ayan
# Processing Record 22 of Set 5 | nouadhibou
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | lompoc
# Processing Record 27 of Set 5 | dolores
# Processing Record 28 of Set 5 | concepcion
# Processing Record 29 of Set 5 | bonthe
# Processing Record 30 of Set 5 | college
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | ipubi
# Processing Record 33 of Set 5 | bubaque
# Processing Record 34 of Set 5 | trindade
# Processing Record 35 of Set 5 | taoudenni
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | carnarvon
# Processing Record 38 of Set 5 | saint-prosper
# Processing Record 39 of Set 5 | dunedin
# Processing Record 40 of Set 5 | qui nhon
# Processing Record 41 of Set 5 | mahibadhoo
# Processing Record 42 of Set 5 | waipawa
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 5 | natalio
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | roald
# Processing Record 48 of Set 5 | rozivka
# Processing Record 49 of Set 5 | pacifica
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | zheleznodorozhnyy
# Processing Record 3 of Set 6 | yulara
# Processing Record 4 of Set 6 | constitucion
# Processing Record 5 of Set 6 | quatre cocos
# Processing Record 6 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 6 | severobaykalsk
# Processing Record 8 of Set 6 | kruisfontein
# Processing Record 9 of Set 6 | wuwei
# Processing Record 10 of Set 6 | havre-saint-pierre
# Processing Record 11 of Set 6 | chivay
# Processing Record 12 of Set 6 | hobyo
# Processing Record 13 of Set 6 | butembo
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | tabory
# Processing Record 17 of Set 6 | norman wells
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | dungarvan
# Processing Record 20 of Set 6 | trinidad
# Processing Record 21 of Set 6 | bodaybo
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | sarankhola
# Processing Record 24 of Set 6 | moree
# Processing Record 25 of Set 6 | nizhniy ufaley
# Processing Record 26 of Set 6 | dmytrivka
# Processing Record 27 of Set 6 | juneau
# Processing Record 28 of Set 6 | akureyri
# Processing Record 29 of Set 6 | chandler
# Processing Record 30 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 31 of Set 6 | saint anthony
# Processing Record 32 of Set 6 | habiganj
# Processing Record 33 of Set 6 | port hardy
# Processing Record 34 of Set 6 | ewo
# Processing Record 35 of Set 6 | bose
# Processing Record 36 of Set 6 | avera
# Processing Record 37 of Set 6 | ambovombe
# Processing Record 38 of Set 6 | tenamaxtlan
# Processing Record 39 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 6 | helmstedt
# Processing Record 41 of Set 6 | honiara
# Processing Record 42 of Set 6 | sao desiderio
# Processing Record 43 of Set 6 | klaksvik
# Processing Record 44 of Set 6 | georgetown
# Processing Record 45 of Set 6 | chimbote
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | iralaya
# Processing Record 48 of Set 6 | kommunar
# Processing Record 49 of Set 6 | bilma
# Processing Record 50 of Set 6 | padang
# Processing Record 1 of Set 7 | dingle
# Processing Record 2 of Set 7 | ahuimanu
# Processing Record 3 of Set 7 | ostrovnoy
# Processing Record 4 of Set 7 | necochea
# Processing Record 5 of Set 7 | payson
# Processing Record 6 of Set 7 | vila velha
# Processing Record 7 of Set 7 | pirapozinho
# Processing Record 8 of Set 7 | bara
# Processing Record 9 of Set 7 | kizukuri
# Processing Record 10 of Set 7 | ko samui
# Processing Record 11 of Set 7 | homer
# Processing Record 12 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 7 | vostok
# Processing Record 14 of Set 7 | opotiki
# Processing Record 15 of Set 7 | half moon bay
# Processing Record 16 of Set 7 | vardo
# Processing Record 17 of Set 7 | mumford
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | marathon
# Processing Record 20 of Set 7 | solnechnyy
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | hasaki
# Processing Record 23 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 24 of Set 7 | banavar
# Processing Record 25 of Set 7 | adamas
# Processing Record 26 of Set 7 | saint-pierre
# Processing Record 27 of Set 7 | allahganj
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | safranbolu
# Processing Record 30 of Set 7 | krasnoyarskiy
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | sassari
# Processing Record 33 of Set 7 | general roca
# Processing Record 34 of Set 7 | edd
# Processing Record 35 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 7 | mbaiki
# Processing Record 37 of Set 7 | cobija
# Processing Record 38 of Set 7 | selikhino
# Processing Record 39 of Set 7 | makakilo city
# Processing Record 40 of Set 7 | vao
# Processing Record 41 of Set 7 | xiongyue
# Processing Record 42 of Set 7 | ajdabiya
# Processing Record 43 of Set 7 | bend
# Processing Record 44 of Set 7 | maralal
# Processing Record 45 of Set 7 | kokkola
# Processing Record 46 of Set 7 | galle
# Processing Record 47 of Set 7 | bemidji
# Processing Record 48 of Set 7 | borogontsy
# Processing Record 49 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 7 | zhuhai
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | north bend
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | burkburnett
# Processing Record 5 of Set 8 | teguldet
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | ler
# Processing Record 8 of Set 8 | santa helena
# Processing Record 9 of Set 8 | pangnirtung
# Processing Record 10 of Set 8 | soyo
# Processing Record 11 of Set 8 | simao
# Processing Record 12 of Set 8 | mongoumba
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | karaton
# Processing Record 15 of Set 8 | grand gaube
# Processing Record 16 of Set 8 | egvekinot
# Processing Record 17 of Set 8 | akyab
# Processing Record 18 of Set 8 | aitape
# Processing Record 19 of Set 8 | bondo
# Processing Record 20 of Set 8 | mayo
# Processing Record 21 of Set 8 | westerland
# Processing Record 22 of Set 8 | loubomo
# Processing Record 23 of Set 8 | kota kinabalu
# Processing Record 24 of Set 8 | iringa
# Processing Record 25 of Set 8 | gilroy
# Processing Record 26 of Set 8 | alghero
# Processing Record 27 of Set 8 | oum hadjer
# Processing Record 28 of Set 8 | oskarshamn
# Processing Record 29 of Set 8 | hami
# Processing Record 30 of Set 8 | coquimbo
# Processing Record 31 of Set 8 | leh
# Processing Record 32 of Set 8 | teguise
# Processing Record 33 of Set 8 | madimba
# Processing Record 34 of Set 8 | melfi
# Processing Record 35 of Set 8 | nenjiang
# Processing Record 36 of Set 8 | ambunti
# Processing Record 37 of Set 8 | yantai
# Processing Record 38 of Set 8 | havelock
# Processing Record 39 of Set 8 | kodiak
# Processing Record 40 of Set 8 | thunder bay
# Processing Record 41 of Set 8 | san carlos
# Processing Record 42 of Set 8 | sayville
# Processing Record 43 of Set 8 | nelson bay
# Processing Record 44 of Set 8 | shahreza
# Processing Record 45 of Set 8 | uyuni
# Processing Record 46 of Set 8 | montepuez
# Processing Record 47 of Set 8 | chifeng
# Processing Record 48 of Set 8 | faanui
# Processing Record 49 of Set 8 | langenburg
# Processing Record 50 of Set 8 | genhe
# Processing Record 1 of Set 9 | oranjestad
# Processing Record 2 of Set 9 | kilimatinde
# Processing Record 3 of Set 9 | kabare
# Processing Record 4 of Set 9 | ola
# Processing Record 5 of Set 9 | hofn
# Processing Record 6 of Set 9 | belle fourche
# Processing Record 7 of Set 9 | krasnoselkup
# Processing Record 8 of Set 9 | werda
# Processing Record 9 of Set 9 | ao luk
# City not found. Skipping...
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | puerto escondido
# Processing Record 12 of Set 9 | cidreira
# Processing Record 13 of Set 9 | la romana
# Processing Record 14 of Set 9 | quzhou
# Processing Record 15 of Set 9 | champerico
# Processing Record 16 of Set 9 | lahij
# Processing Record 17 of Set 9 | san cataldo
# Processing Record 18 of Set 9 | ban nahin
# Processing Record 19 of Set 9 | anage
# Processing Record 20 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | svetlyy
# Processing Record 23 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 9 | khotynets
# Processing Record 25 of Set 9 | alyangula
# Processing Record 26 of Set 9 | lorengau
# Processing Record 27 of Set 9 | beringovskiy
# Processing Record 28 of Set 9 | victoria
# Processing Record 29 of Set 9 | lalibela
# Processing Record 30 of Set 9 | pinawa
# Processing Record 31 of Set 9 | lagoa
# Processing Record 32 of Set 9 | mankera
# Processing Record 33 of Set 9 | san quintin
# Processing Record 34 of Set 9 | iqaluit
# Processing Record 35 of Set 9 | quelimane
# Processing Record 36 of Set 9 | kholodnyy
# Processing Record 37 of Set 9 | berlevag
# Processing Record 38 of Set 9 | vestmanna
# Processing Record 39 of Set 9 | sept-iles
# Processing Record 40 of Set 9 | tyulyachi
# Processing Record 41 of Set 9 | saint george
# Processing Record 42 of Set 9 | carmarthen
# Processing Record 43 of Set 9 | kungurtug
# Processing Record 44 of Set 9 | tessaoua
# Processing Record 45 of Set 9 | wanning
# Processing Record 46 of Set 9 | kiunga
# Processing Record 47 of Set 9 | lahad datu
# Processing Record 48 of Set 9 | methoni
# Processing Record 49 of Set 9 | sredec
# City not found. Skipping...
# Processing Record 50 of Set 9 | ust-kalmanka
# Processing Record 1 of Set 10 | jaisalmer
# Processing Record 2 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 3 of Set 10 | upata
# Processing Record 4 of Set 10 | ulladulla
# Processing Record 5 of Set 10 | hovd
# Processing Record 6 of Set 10 | kirakira
# Processing Record 7 of Set 10 | okakarara
# Processing Record 8 of Set 10 | morro bay
# Processing Record 9 of Set 10 | bay roberts
# Processing Record 10 of Set 10 | ilulissat
# Processing Record 11 of Set 10 | daru
# Processing Record 12 of Set 10 | hiroshima
# Processing Record 13 of Set 10 | puerto cabezas
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | kharp
# Processing Record 16 of Set 10 | araci
# Processing Record 17 of Set 10 | along
# Processing Record 18 of Set 10 | newport
# Processing Record 19 of Set 10 | alofi
# Processing Record 20 of Set 10 | sampit
# Processing Record 21 of Set 10 | virden
# Processing Record 22 of Set 10 | kjopsvik
# Processing Record 23 of Set 10 | udachnyy
# Processing Record 24 of Set 10 | west wendover
# Processing Record 25 of Set 10 | manica
# Processing Record 26 of Set 10 | aksarka
# Processing Record 27 of Set 10 | igurusi
# Processing Record 28 of Set 10 | mogadishu
# Processing Record 29 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 10 | golden
# Processing Record 31 of Set 10 | seguela
# Processing Record 32 of Set 10 | ballina
# Processing Record 33 of Set 10 | elbistan
# Processing Record 34 of Set 10 | broken hill
# Processing Record 35 of Set 10 | weihe
# Processing Record 36 of Set 10 | ferrol
# Processing Record 37 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 10 | villarrobledo
# Processing Record 39 of Set 10 | rio gallegos
# Processing Record 40 of Set 10 | dawei
# Processing Record 41 of Set 10 | alamogordo
# Processing Record 42 of Set 10 | berdigestyakh
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | zuya
# Processing Record 45 of Set 10 | namanyere
# Processing Record 46 of Set 10 | alice springs
# Processing Record 47 of Set 10 | martyush
# Processing Record 48 of Set 10 | codajas
# Processing Record 49 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 50 of Set 10 | kerch
# Processing Record 1 of Set 11 | hare bay
# Processing Record 2 of Set 11 | svetlaya
# Processing Record 3 of Set 11 | kununurra
# Processing Record 4 of Set 11 | uruacu
# Processing Record 5 of Set 11 | sandwick
# Processing Record 6 of Set 11 | hanzhong
# Processing Record 7 of Set 11 | ushtobe
# Processing Record 8 of Set 11 | sinnamary
# Processing Record 9 of Set 11 | natal
# Processing Record 10 of Set 11 | ixtapa
# Processing Record 11 of Set 11 | lonavale
# Processing Record 12 of Set 11 | gorno-altaysk
# Processing Record 13 of Set 11 | breytovo
# Processing Record 14 of Set 11 | skelleftea
# Processing Record 15 of Set 11 | tricase
# Processing Record 16 of Set 11 | gariaband
# Processing Record 17 of Set 11 | la primavera
# Processing Record 18 of Set 11 | pauini
# Processing Record 19 of Set 11 | cairns
# Processing Record 20 of Set 11 | marsh harbour
# Processing Record 21 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 11 | lo arado
# Processing Record 23 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 24 of Set 11 | prabumulih
# Processing Record 25 of Set 11 | tougan
# Processing Record 26 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 11 | gornopravdinsk
# Processing Record 28 of Set 11 | zhoukou
# Processing Record 29 of Set 11 | pyaozerskiy
# Processing Record 30 of Set 11 | yalutorovsk
# Processing Record 31 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 32 of Set 11 | zhanaozen
# Processing Record 33 of Set 11 | biak
# Processing Record 34 of Set 11 | yola
# Processing Record 35 of Set 11 | cayenne
# Processing Record 36 of Set 11 | humaita
# Processing Record 37 of Set 11 | mlonggo
# Processing Record 38 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 39 of Set 11 | sao joao da barra
# Processing Record 40 of Set 11 | marsabit
# Processing Record 41 of Set 11 | carbonia
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | tessalit
# Processing Record 44 of Set 11 | la sarre
# Processing Record 45 of Set 11 | antsohihy
# Processing Record 46 of Set 11 | bratsk
# Processing Record 47 of Set 11 | sabibah
# City not found. Skipping...
# Processing Record 48 of Set 11 | nemuro
# Processing Record 49 of Set 11 | katherine
# Processing Record 50 of Set 11 | charagua
# Processing Record 1 of Set 12 | baykit
# Processing Record 2 of Set 12 | muros
# Processing Record 3 of Set 12 | usinsk
# Processing Record 4 of Set 12 | ketchikan
# Processing Record 5 of Set 12 | kwinana
# Processing Record 6 of Set 12 | xai-xai
# Processing Record 7 of Set 12 | beitbridge
# Processing Record 8 of Set 12 | alugan
# Processing Record 9 of Set 12 | nicoya
# Processing Record 10 of Set 12 | ardrishaig
# Processing Record 11 of Set 12 | marsa matruh
# Processing Record 12 of Set 12 | urozhayne
# City not found. Skipping...
# Processing Record 13 of Set 12 | ronne
# Processing Record 14 of Set 12 | namibe
# Processing Record 15 of Set 12 | eskil
# Processing Record 16 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 12 | morondava
# Processing Record 18 of Set 12 | ponta delgada
# Processing Record 19 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 20 of Set 12 | plyussa
# Processing Record 21 of Set 12 | sesheke
# Processing Record 22 of Set 12 | coari
# Processing Record 23 of Set 12 | touros
# Processing Record 24 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 12 | swan river
# Processing Record 26 of Set 12 | alta floresta
# Processing Record 27 of Set 12 | usoke
# Processing Record 28 of Set 12 | bhadrachalam
# Processing Record 29 of Set 12 | alta
# Processing Record 30 of Set 12 | sheltozero
# Processing Record 31 of Set 12 | kemin
# Processing Record 32 of Set 12 | dovbysh
# Processing Record 33 of Set 12 | barra patuca
# Processing Record 34 of Set 12 | kollumerland
# City not found. Skipping...
# Processing Record 35 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 12 | kindu
# Processing Record 37 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | aykhal
# Processing Record 40 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 12 | orvieto
# Processing Record 42 of Set 12 | komsomolskiy
# Processing Record 43 of Set 12 | kenai
# Processing Record 44 of Set 12 | vangaindrano
# Processing Record 45 of Set 12 | mastic beach
# Processing Record 46 of Set 12 | karratha
# Processing Record 47 of Set 12 | paez
# Processing Record 48 of Set 12 | niort
# Processing Record 49 of Set 12 | byron bay
# Processing Record 50 of Set 12 | malanje
# Processing Record 1 of Set 13 | payo
# Processing Record 2 of Set 13 | eyl
# Processing Record 3 of Set 13 | yaan
# Processing Record 4 of Set 13 | marzuq
# Processing Record 5 of Set 13 | agadir
# Processing Record 6 of Set 13 | nabire
# Processing Record 7 of Set 13 | krasnyy chikoy
# Processing Record 8 of Set 13 | anadyr
# Processing Record 9 of Set 13 | kodinar
# Processing Record 10 of Set 13 | garowe
# Processing Record 11 of Set 13 | mineiros
# Processing Record 12 of Set 13 | mayna
# Processing Record 13 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 13 | kawalu
# Processing Record 15 of Set 13 | cockburn town
# Processing Record 16 of Set 13 | sistranda
# Processing Record 17 of Set 13 | amazar
# Processing Record 18 of Set 13 | chicama
# Processing Record 19 of Set 13 | marovoay
# Processing Record 20 of Set 13 | lewiston
# Processing Record 21 of Set 13 | hohhot
# Processing Record 22 of Set 13 | pokhara
# Processing Record 23 of Set 13 | civitanova marche
# Processing Record 24 of Set 13 | tateyama
# Processing Record 25 of Set 13 | domodossola
# Processing Record 26 of Set 13 | riaba
# City not found. Skipping...
# Processing Record 27 of Set 13 | williams lake
# Processing Record 28 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 13 | havoysund
# Processing Record 30 of Set 13 | peace river
# Processing Record 31 of Set 13 | fontenay-le-comte
# Processing Record 32 of Set 13 | manaure
# Processing Record 33 of Set 13 | athabasca
# Processing Record 34 of Set 13 | corinto
# Processing Record 35 of Set 13 | slupsk
# Processing Record 36 of Set 13 | aquiraz
# Processing Record 37 of Set 13 | mathathane
# Processing Record 38 of Set 13 | port blair
# Processing Record 39 of Set 13 | katsuura
# Processing Record 40 of Set 13 | pasighat
# Processing Record 41 of Set 13 | kharod
# Processing Record 42 of Set 13 | sidi ali
# Processing Record 43 of Set 13 | coos bay
# Processing Record 44 of Set 13 | banswada
# Processing Record 45 of Set 13 | karistos
# City not found. Skipping...
# Processing Record 46 of Set 13 | tunceli
# Processing Record 47 of Set 13 | bodden town
# Processing Record 48 of Set 13 | miram shah
# Processing Record 49 of Set 13 | catuday
# Processing Record 50 of Set 13 | camp verde
# Processing Record 1 of Set 14 | aksu
# Processing Record 2 of Set 14 | pochutla
# Processing Record 3 of Set 14 | brownsville
# Processing Record 4 of Set 14 | teneguiban
# City not found. Skipping...
# Processing Record 5 of Set 14 | rocha
# Processing Record 6 of Set 14 | itarema
# Processing Record 7 of Set 14 | tarpon springs
# Processing Record 8 of Set 14 | ouesso
# Processing Record 9 of Set 14 | suao
# City not found. Skipping...
# Processing Record 10 of Set 14 | nagsabaran
# City not found. Skipping...
# Processing Record 11 of Set 14 | kashan
# Processing Record 12 of Set 14 | pacific grove
# Processing Record 13 of Set 14 | smithers
# Processing Record 14 of Set 14 | russell
# Processing Record 15 of Set 14 | ho
# City not found. Skipping...
# Processing Record 16 of Set 14 | auki
# Processing Record 17 of Set 14 | gambela
# Processing Record 18 of Set 14 | ust-tsilma
# Processing Record 19 of Set 14 | azuaga
# Processing Record 20 of Set 14 | lazaro cardenas
# Processing Record 21 of Set 14 | price
# Processing Record 22 of Set 14 | salalah
# Processing Record 23 of Set 14 | mayumba
# Processing Record 24 of Set 14 | puerto cabello
# Processing Record 25 of Set 14 | bayji
# Processing Record 26 of Set 14 | mombetsu
# Processing Record 27 of Set 14 | rawson
# Processing Record 28 of Set 14 | kasongo-lunda
# Processing Record 29 of Set 14 | himora
# City not found. Skipping...
# Processing Record 30 of Set 14 | laurel
# Processing Record 31 of Set 14 | carutapera
# Processing Record 32 of Set 14 | sioux lookout
# Processing Record 33 of Set 14 | comodoro rivadavia
# Processing Record 34 of Set 14 | kurchum
# Processing Record 35 of Set 14 | teknaf
# Processing Record 36 of Set 14 | vega de alatorre
# Processing Record 37 of Set 14 | ziezmariai
# Processing Record 38 of Set 14 | laramie
# Processing Record 39 of Set 14 | haines junction
# Processing Record 40 of Set 14 | ekhabi
# Processing Record 41 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 14 | acarau
# Processing Record 43 of Set 14 | hualmay
# Processing Record 44 of Set 14 | gravdal
# Processing Record 45 of Set 14 | yuzawa
# Processing Record 46 of Set 14 | yandoon
# City not found. Skipping...
# Processing Record 47 of Set 14 | mana
# Processing Record 48 of Set 14 | arcachon
# Processing Record 49 of Set 14 | sitamau
# Processing Record 50 of Set 14 | xinxiang
# Processing Record 1 of Set 15 | sainte-anne-des-monts
# Processing Record 2 of Set 15 | itupiranga
# Processing Record 3 of Set 15 | lexington
# Processing Record 4 of Set 15 | san juan
# Processing Record 5 of Set 15 | kidal
# Processing Record 6 of Set 15 | jumla
# Processing Record 7 of Set 15 | coihaique
# Processing Record 8 of Set 15 | talnakh
# Processing Record 9 of Set 15 | lavrentiya
# Processing Record 10 of Set 15 | riviere-au-renard
# Processing Record 11 of Set 15 | niono
# Processing Record 12 of Set 15 | naze
# Processing Record 13 of Set 15 | french harbor
# Processing Record 14 of Set 15 | tacuarembo
# Processing Record 15 of Set 15 | mocuba
# Processing Record 16 of Set 15 | jiwani
# Processing Record 17 of Set 15 | tabou
# Processing Record 18 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 15 | mayfield
# Processing Record 20 of Set 15 | ucluelet
# Processing Record 21 of Set 15 | jambi
# Processing Record 22 of Set 15 | shingu
# Processing Record 23 of Set 15 | karpathos
# Processing Record 24 of Set 15 | deer lake
# Processing Record 25 of Set 15 | kulhudhuffushi
# Processing Record 26 of Set 15 | severnoye
# Processing Record 27 of Set 15 | araouane
# Processing Record 28 of Set 15 | santo andre
# Processing Record 29 of Set 15 | biloela
# Processing Record 30 of Set 15 | strezhevoy
# Processing Record 31 of Set 15 | mandsaur
# Processing Record 32 of Set 15 | rantepao
# Processing Record 33 of Set 15 | bryan
# Processing Record 34 of Set 15 | chalmette
# Processing Record 35 of Set 15 | bo
# City not found. Skipping...
# Processing Record 36 of Set 15 | northam
# Processing Record 37 of Set 15 | santa lucia
# Processing Record 38 of Set 15 | maun
# Processing Record 39 of Set 15 | tara
# Processing Record 40 of Set 15 | klyuchi
# Processing Record 41 of Set 15 | arman
# Processing Record 42 of Set 15 | syracuse
# Processing Record 43 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 44 of Set 15 | dangriga
# Processing Record 45 of Set 15 | weligama
# Processing Record 46 of Set 15 | paamiut
# Processing Record 47 of Set 15 | mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     10.72        80          42
# 1       Eureka      US  40.8021 -124.1637     38.59        58           0
# 2  Port Alfred      ZA -33.5906   26.8910     77.76        82          45
# 3      Rikitea      PF -23.1203 -134.9692     77.70        73          46
# 4       Torbay      CA  47.6666  -52.7314     24.58        82          75
# 5        Buala      SB  -8.1450  159.5921     78.40        87         100
# 6     Bac Lieu      VN   9.2850  105.7244     77.32        79          88
# 7       Xining      CN  36.6167  101.7667     16.02        87         100
# 8      Qaanaaq      GL  77.4840  -69.3632     -4.40        68         100
# 9    Jamestown      US  42.0970  -79.2353     12.52        65           0
#
#    Wind Speed Current Description
# 0        5.19    scattered clouds
# 1        5.48           clear sky
# 2       14.03    scattered clouds
# 3       17.78    scattered clouds
# 4       16.11       broken clouds
# 5        7.87          light rain
# 6        8.90     overcast clouds
# 7        3.24     overcast clouds
# 8        5.79     overcast clouds
# 9        1.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
